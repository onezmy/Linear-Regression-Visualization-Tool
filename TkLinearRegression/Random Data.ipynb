# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

# %%
mu, sigma = 3, 0.5 # mean and standard deviation
n = 150
x = np.random.normal(mu, sigma, n)
y = []
for i in range(len(x)):
    y.append(5.5*x[i]+1.5 + np.random.normal(0,1,1))

# %%
y = np.array(y).reshape(n,)
x = x.reshape(n,)
plt.scatter(x,y) 
plt.show()

# %%
df = pd.DataFrame({'x':x,'y':y})

# %%
df.to_csv('sampe_y=5.5x+1.5.csv',index=False)

# %%
df.to_csv('1.csv',index=False)

# %%
m = 0
c = 0
L = 0.0001 
n = len(x)
X_num, Y_num = [], []
X_num = np.array(x).reshape(n,)
Y_num = np.array(y).reshape(n,)
for i in range(10): 
    Y_pred = m*X_num + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X_num * (Y_num - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y_num - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c
    fig = plt.figure(figsize = (5, 20))
    ax = fig.add_subplot()
    # ax.scatter(X_num, Y_num)
    x = np.arange(min(X_num)-1, max(X_num)+1)
    ax.plot(x, m * x + c, '-')
    plt.xlim(min(X_num)-1, max(X_num)+1)
    plt.show()
    print(m,c)
# Out:
# 0.011257533719602312 0.0036371014054765094
# 0.022491729004820927 0.007266657226018258
# 0.03370263424272973 0.010888683105746606
# 0.04489029772008268 0.014503194656348296
# 0.05605476762352186 0.01811020745714268
# 0.06719609203978501 0.021709737055148857
# 0.07831431895591265 0.025301798965152597
# 0.0894094962594548 0.02888640866977321
# 0.10048167173867721 0.032463581619530224
# 0.11153089308276726 0.036033333232909914

# %%
fig = plt.figure(figsize = (5, 5),dpi=50)
ax=fig.add_subplot()
ax.scatter(x, y) 
ax.plot([min(x), max(x)], [min(y), max(y)], color='red') 
im =ax

# %%
i
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20776\1660183834.py in <module>
# ----> 1 im.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'
